# %% [markdown]
# # 🐍 AI Travel Agent with Microsoft Agent Framework (Python)
#
# ## 📋 Scenario Overview
#
# This notebook demonstrates how to build an intelligent travel planning agent using the Microsoft Agent Framework for Python. The agent leverages GitHub Models to automatically generate personalized day-trip itineraries for random destinations worldwide.
#
# **Key Features:**
# - 🎲 **Smart Destination Selection**: Custom tool function for random destination picking
# - 🗺️ **Detailed Itinerary Generation**: AI-powered travel planning with local recommendations
# - 🔄 **Async Processing**: Uses asyncio for efficient API communication
# - 🛠️ **Tool Integration**: Demonstrates function calling capabilities in AI agents
#
# ## 🏗️ Technical Implementation
#
# ### Core Components
# - **Agent Framework**: Python implementation of Microsoft's agent orchestration system
# - **GitHub Models API**: Access to state-of-the-art language models via GitHub's inference service
# - **OpenAI Compatibility**: Uses OpenAI client patterns with GitHub Models backend
# - **Environment Management**: Secure credential handling with python-dotenv
#
# ### Architecture Flow
# ```python
# User Request → ChatAgent → GitHub Models API ↔ get_random_destination()
#                      ↓
#               Travel Itinerary Response
# ```
#
# ### Key Classes & Methods
# - `ChatAgent`: Main conversational agent orchestrator
# - `OpenAIChatClient`: GitHub Models API client wrapper
# - `get_random_destination()`: Custom tool function for destination selection
# - Environment variables: Secure API configuration management
#
# ## ⚙️ Prerequisites & Setup
#
# **Required Dependencies:**
# ```bash
#
# pip install agent-framework-core -U
# ```
#
# **Environment Configuration (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **GitHub Models Access:**
# 1. Sign up for GitHub Models access
# 2. Generate a personal access token
# 3. Configure environment variables as shown above
#
# ## 🚀 Usage Instructions
#
# Execute the cells below in sequence to:
# 1. Import required libraries and load environment variables
# 2. Define the random destination generator tool
# 3. Create and configure the AI agent
# 4. Run travel planning requests and view results
#
# Let's build an intelligent travel planning assistant! 🌟

# %%
# ! pip install agent-framework-core -U
# Out:
# Collecting agent-framework-core
#   Downloading agent_framework_core-1.0.0b251108-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: typing-extensions in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core) (4.12.2)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core) (2.10.1)
# Requirement already satisfied: pydantic-settings<3,>=2 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core) (2.11.0)
# Requirement already satisfied: opentelemetry-api>=1.24 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.24 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.36.0 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core) (1.38.0)
# Collecting opentelemetry-semantic-conventions-ai>=0.4.13 (from agent-framework-core)
#   Downloading opentelemetry_semantic_conventions_ai-0.4.13-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: openai>=1.99.0 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from agent-framework-core) (2.7.1)
# Collecting azure-identity<2,>=1 (from agent-framework-core)
#   Downloading azure_identity-1.25.1-py3-none-any.whl.metadata (88 kB)
# Collecting mcp>=1.13 (from mcp[ws]>=1.13->agent-framework-core)
#   Downloading mcp-1.21.0-py3-none-any.whl.metadata (85 kB)
# Requirement already satisfied: packaging>=24.1 in c:\users\malte\appdata\roaming\python\python313\site-packages (from agent-framework-core) (24.1)
# Collecting azure-core>=1.31.0 (from azure-identity<2,>=1->agent-framework-core)
#   Downloading azure_core-1.36.0-py3-none-any.whl.metadata (47 kB)
# Collecting cryptography>=2.5 (from azure-identity<2,>=1->agent-framework-core)
#   Downloading cryptography-46.0.3-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting msal>=1.30.0 (from azure-identity<2,>=1->agent-framework-core)
#   Downloading msal-1.34.0-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=1.2.0 (from azure-identity<2,>=1->agent-framework-core)
#   Downloading msal_extensions-1.3.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=2->agent-framework-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=2->agent-framework-core) (2.27.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from pydantic-settings<3,>=2->agent-framework-core) (1.2.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from pydantic-settings<3,>=2->agent-framework-core) (0.4.2)
# Requirement already satisfied: requests>=2.21.0 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.32.5)
# Collecting cffi>=2.0.0 (from cryptography>=2.5->azure-identity<2,>=1->agent-framework-core)
#   Using cached cffi-2.0.0-cp313-cp313-win_amd64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=2.5->azure-identity<2,>=1->agent-framework-core)
#   Using cached pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Requirement already satisfied: anyio>=4.5 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (4.6.2.post1)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.27.2)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (4.25.1)
# Collecting pydantic<3,>=2 (from agent-framework-core)
#   Downloading pydantic-2.12.4-py3-none-any.whl.metadata (89 kB)
# Collecting pyjwt>=2.10.1 (from pyjwt[crypto]>=2.10.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core)
#   Downloading PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting python-multipart>=0.0.9 (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core)
#   Using cached python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting pywin32>=310 (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core)
#   Using cached pywin32-311-cp313-cp313-win_amd64.whl.metadata (10 kB)
# Collecting sse-starlette>=1.6.1 (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core)
#   Downloading sse_starlette-3.0.3-py3-none-any.whl.metadata (12 kB)
# Collecting starlette>=0.27 (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core)
#   Downloading starlette-0.50.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: uvicorn>=0.31.1 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.38.0)
# Collecting pydantic-core==2.41.5 (from pydantic<3,>=2->agent-framework-core)
#   Downloading pydantic_core-2.41.5-cp313-cp313-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-extensions (from agent-framework-core)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: idna>=2.8 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from anyio>=4.5->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from anyio>=4.5->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (1.3.1)
# Requirement already satisfied: certifi in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.14.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.28.0)
# Requirement already satisfied: websockets>=15.0.1 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from mcp[ws]>=1.13->agent-framework-core) (15.0.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.2.3)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from openai>=1.99.0->agent-framework-core) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from openai>=1.99.0->agent-framework-core) (0.11.1)
# Requirement already satisfied: tqdm>4 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from openai>=1.99.0->agent-framework-core) (4.67.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-api>=1.24->agent-framework-core) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.24->agent-framework-core) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core) (1.71.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.66.2 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core) (1.76.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core) (1.38.0)
# Requirement already satisfied: protobuf<7.0,>=5.0 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-proto==1.38.0->opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core) (6.33.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-sdk>=1.24->agent-framework-core) (0.59b0)
# Collecting anyio>=4.5 (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core)
#   Downloading anyio-4.11.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: colorama in c:\users\malte\appdata\roaming\python\python313\site-packages (from tqdm>4->openai>=1.99.0->agent-framework-core) (0.4.6)
# Requirement already satisfied: click>=7.0 in c:\users\malte\appdata\local\programs\python\python313\lib\site-packages (from uvicorn>=0.31.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (8.3.0)
# Downloading agent_framework_core-1.0.0b251108-py3-none-any.whl (318 kB)
# Downloading azure_identity-1.25.1-py3-none-any.whl (191 kB)
# Downloading azure_core-1.36.0-py3-none-any.whl (213 kB)
# Downloading cryptography-46.0.3-cp311-abi3-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    -------------- ------------------------- 1.3/3.5 MB 7.3 MB/s eta 0:00:01
#    -------------------------------- ------- 2.9/3.5 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 6.9 MB/s  0:00:00
# Using cached cffi-2.0.0-cp313-cp313-win_amd64.whl (183 kB)
# Downloading mcp-1.21.0-py3-none-any.whl (173 kB)
# Downloading pydantic-2.12.4-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp313-cp313-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ------------------------- -------------- 1.3/2.0 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 5.2 MB/s  0:00:00
# Downloading msal-1.34.0-py3-none-any.whl (116 kB)
# Downloading PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Downloading msal_extensions-1.3.1-py3-none-any.whl (20 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading opentelemetry_semantic_conventions_ai-0.4.13-py3-none-any.whl (6.1 kB)
# Using cached python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Using cached pywin32-311-cp313-cp313-win_amd64.whl (9.5 MB)
# Downloading sse_starlette-3.0.3-py3-none-any.whl (11 kB)
# Downloading anyio-4.11.0-py3-none-any.whl (109 kB)
# Downloading starlette-0.50.0-py3-none-any.whl (74 kB)
# Using cached pycparser-2.23-py3-none-any.whl (118 kB)
# Installing collected packages: pywin32, typing-extensions, python-multipart, pyjwt, pycparser, opentelemetry-semantic-conventions-ai, anyio, starlette, sse-starlette, pydantic-core, cffi, azure-core, pydantic, cryptography, msal, mcp, msal-extensions, azure-identity, agent-framework-core
#
#   Attempting uninstall: pywin32
#
#     Found existing installation: pywin32 307
#
#    ----------------------------------------  0/19 [pywin32]
#     Uninstalling pywin32-307:
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#       Successfully uninstalled pywin32-307
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#    ----------------------------------------  0/19 [pywin32]
#   Attempting uninstall: typing-extensions
#    ----------------------------------------  0/19 [pywin32]
#     Found existing installation: typing_extensions 4.12.2
#    ----------------------------------------  0/19 [pywin32]
#     Uninstalling typing_extensions-4.12.2:
#    ----------------------------------------  0/19 [pywin32]
#    -- -------------------------------------  1/19 [typing-extensions]
#    -- -------------------------------------  1/19 [typing-extensions]
#    -- -------------------------------------  1/19 [typing-extensions]
#    -- -------------------------------------  1/19 [typing-extensions]
#    -- -------------------------------------  1/19 [typing-extensions]
#    -- -------------------------------------  1/19 [typing-extensions]
#    -- -------------------------------------  1/19 [typing-extensions]
#    -- -------------------------------------  1/19 [typing-extensions]
#    -- -------------------------------------  1/19 [typing-extensions]
#    -- -------------------------------------  1/19 [typing-extensions]
#    -- -------------------------------------  1/19 [typing-extensions]
#    -- -------------------------------------  1/19 [typing-extensions]
#    -- -------------------------------------  1/19 [typing-extensions]
#    -- -------------------------------------  1/19 [typing-extensions]
#    -- -------------------------------------  1/19 [typing-extensions]
#    -- -------------------------------------  1/19 [typing-extensions]
#    -- -------------------------------------  1/19 [typing-extensions]
#    -- -------------------------------------  1/19 [typing-extensions]
#    -- -------------------------------------  1/19 [typing-extensions]
#       Successfully uninstalled typing_extensions-4.12.2
#    -- -------------------------------------  1/19 [typing-extensions]
#    -- -------------------------------------  1/19 [typing-extensions]
#    ------ ---------------------------------  3/19 [pyjwt]
#    ------ ---------------------------------  3/19 [pyjwt]
#    -------- -------------------------------  4/19 [pycparser]
#    -------- -------------------------------  4/19 [pycparser]
#    ------- ----------------------  5/19 [opentelemetry-semantic-conventions-ai]
#   Attempting uninstall: anyio
#    ------- ----------------------  5/19 [opentelemetry-semantic-conventions-ai]
#     Found existing installation: anyio 4.6.2.post1
#    ------- ----------------------  5/19 [opentelemetry-semantic-conventions-ai]
#     Uninstalling anyio-4.6.2.post1:
#    ------- ----------------------  5/19 [opentelemetry-semantic-conventions-ai]
#       Successfully uninstalled anyio-4.6.2.post1
#    ------- ----------------------  5/19 [opentelemetry-semantic-conventions-ai]
#    ------------ ---------------------------  6/19 [anyio]
#    ------------ ---------------------------  6/19 [anyio]
#    ------------ ---------------------------  6/19 [anyio]
#    ------------ ---------------------------  6/19 [anyio]
#    ------------ ---------------------------  6/19 [anyio]
#    -------------- -------------------------  7/19 [starlette]
#    -------------- -------------------------  7/19 [starlette]
#    -------------- -------------------------  7/19 [starlette]
#    -------------- -------------------------  7/19 [starlette]
#    -------------- -------------------------  7/19 [starlette]
#    -------------- -------------------------  7/19 [starlette]
#   Attempting uninstall: pydantic-core
#    -------------- -------------------------  7/19 [starlette]
#     Found existing installation: pydantic_core 2.27.1
#    -------------- -------------------------  7/19 [starlette]
#     Uninstalling pydantic_core-2.27.1:
#    -------------- -------------------------  7/19 [starlette]
#       Successfully uninstalled pydantic_core-2.27.1
#    -------------- -------------------------  7/19 [starlette]
#    ------------------ ---------------------  9/19 [pydantic-core]
#    --------------------- ------------------ 10/19 [cffi]
#    --------------------- ------------------ 10/19 [cffi]
#    --------------------- ------------------ 10/19 [cffi]
#    ----------------------- ---------------- 11/19 [azure-core]
#    ----------------------- ---------------- 11/19 [azure-core]
#    ----------------------- ---------------- 11/19 [azure-core]
#    ----------------------- ---------------- 11/19 [azure-core]
#    ----------------------- ---------------- 11/19 [azure-core]
#    ----------------------- ---------------- 11/19 [azure-core]
#    ----------------------- ---------------- 11/19 [azure-core]
#    ----------------------- ---------------- 11/19 [azure-core]
#    ----------------------- ---------------- 11/19 [azure-core]
#    ----------------------- ---------------- 11/19 [azure-core]
#   Attempting uninstall: pydantic
#    ----------------------- ---------------- 11/19 [azure-core]
#     Found existing installation: pydantic 2.10.1
#    ----------------------- ---------------- 11/19 [azure-core]
#     Uninstalling pydantic-2.10.1:
#    ----------------------- ---------------- 11/19 [azure-core]
#       Successfully uninstalled pydantic-2.10.1
#    ----------------------- ---------------- 11/19 [azure-core]
#    ------------------------- -------------- 12/19 [pydantic]
#    ------------------------- -------------- 12/19 [pydantic]
#    ------------------------- -------------- 12/19 [pydantic]
#    ------------------------- -------------- 12/19 [pydantic]
#    ------------------------- -------------- 12/19 [pydantic]
#    ------------------------- -------------- 12/19 [pydantic]
#    ------------------------- -------------- 12/19 [pydantic]
#    ------------------------- -------------- 12/19 [pydantic]
#    ------------------------- -------------- 12/19 [pydantic]
#    ------------------------- -------------- 12/19 [pydantic]
#    ------------------------- -------------- 12/19 [pydantic]
#    ------------------------- -------------- 12/19 [pydantic]
#    ------------------------- -------------- 12/19 [pydantic]
#    ------------------------- -------------- 12/19 [pydantic]
#    --------------------------- ------------ 13/19 [cryptography]
#    --------------------------- ------------ 13/19 [cryptography]
#    --------------------------- ------------ 13/19 [cryptography]
#    --------------------------- ------------ 13/19 [cryptography]
#    --------------------------- ------------ 13/19 [cryptography]
#    --------------------------- ------------ 13/19 [cryptography]
#    --------------------------- ------------ 13/19 [cryptography]
#    --------------------------- ------------ 13/19 [cryptography]
#    --------------------------- ------------ 13/19 [cryptography]
#    ----------------------------- ---------- 14/19 [msal]
#    ----------------------------- ---------- 14/19 [msal]
#    ----------------------------- ---------- 14/19 [msal]
#    ------------------------------- -------- 15/19 [mcp]
#    ------------------------------- -------- 15/19 [mcp]
#    ------------------------------- -------- 15/19 [mcp]
#    ------------------------------- -------- 15/19 [mcp]
#    ------------------------------- -------- 15/19 [mcp]
#    ------------------------------- -------- 15/19 [mcp]
#    ------------------------------- -------- 15/19 [mcp]
#    ------------------------------- -------- 15/19 [mcp]
#    ------------------------------- -------- 15/19 [mcp]
#    ------------------------------- -------- 15/19 [mcp]
#    ------------------------------- -------- 15/19 [mcp]
#    --------------------------------- ------ 16/19 [msal-extensions]
#    ----------------------------------- ---- 17/19 [azure-identity]
#    ----------------------------------- ---- 17/19 [azure-identity]
#    ----------------------------------- ---- 17/19 [azure-identity]
#    ----------------------------------- ---- 17/19 [azure-identity]
#    ----------------------------------- ---- 17/19 [azure-identity]
#    ----------------------------------- ---- 17/19 [azure-identity]
#    ----------------------------------- ---- 17/19 [azure-identity]
#    ----------------------------------- ---- 17/19 [azure-identity]
#    ----------------------------------- ---- 17/19 [azure-identity]
#    ----------------------------------- ---- 17/19 [azure-identity]
#    ------------------------------------- -- 18/19 [agent-framework-core]
#    ------------------------------------- -- 18/19 [agent-framework-core]
#    ------------------------------------- -- 18/19 [agent-framework-core]
#    ------------------------------------- -- 18/19 [agent-framework-core]
#    ------------------------------------- -- 18/19 [agent-framework-core]
#    ------------------------------------- -- 18/19 [agent-framework-core]
#    ------------------------------------- -- 18/19 [agent-framework-core]
#    ------------------------------------- -- 18/19 [agent-framework-core]
#    ------------------------------------- -- 18/19 [agent-framework-core]
#    ------------------------------------- -- 18/19 [agent-framework-core]
#    ---------------------------------------- 19/19 [agent-framework-core]
#
# Successfully installed agent-framework-core-1.0.0b251108 anyio-4.11.0 azure-core-1.36.0 azure-identity-1.25.1 cffi-2.0.0 cryptography-46.0.3 mcp-1.21.0 msal-1.34.0 msal-extensions-1.3.1 opentelemetry-semantic-conventions-ai-0.4.13 pycparser-2.23 pydantic-2.12.4 pydantic-core-2.41.5 pyjwt-2.10.1 python-multipart-0.0.20 pywin32-311 sse-starlette-3.0.3 starlette-0.50.0 typing-extensions-4.15.0
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 📦 Import Required Libraries
# Standard library imports for system operations and random number generation
import os
from random import randint

# Third-party library for loading environment variables from .env file
from dotenv import load_dotenv

# %%
# 🤖 Import Microsoft Agent Framework Components
# ChatAgent: The main agent class for conversational AI
# OpenAIChatClient: Client for connecting to OpenAI-compatible APIs (including GitHub Models)
from agent_framework import ChatAgent
from agent_framework.openai import OpenAIChatClient

# %%
# 🔧 Load Environment Variables
# This loads configuration from a .env file in the project root
# Required variables: GITHUB_ENDPOINT, GITHUB_TOKEN, GITHUB_MODEL_ID
load_dotenv()
# Out:
# False

# %%
# 🎲 Tool Function: Random Destination Generator
# This function will be available to the agent as a tool
# The agent can call this function to get random vacation destinations
def get_random_destination() -> str:
    """Get a random vacation destination.
    
    Returns:
        str: A randomly selected destination from our predefined list
    """
    # List of popular vacation destinations around the world
    destinations = [
        "Barcelona, Spain",
        "Paris, France", 
        "Berlin, Germany",
        "Tokyo, Japan",
        "Sydney, Australia",
        "New York, USA",
        "Cairo, Egypt",
        "Cape Town, South Africa",
        "Rio de Janeiro, Brazil",
        "Bali, Indonesia"
    ]
    # Return a random destination from the list
    return destinations[randint(0, len(destinations) - 1)]

# %%
# --- This loads the variables from your .env file ---
load_dotenv()

# 🔗 Create OpenAI Chat Client for GitHub Models
# This code now works because the os.environ.get() calls
# will find the variables you set in the .env file.
openai_chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),
    api_key=os.environ.get("GITHUB_TOKEN"), 
    model_id=os.environ.get("GITHUB_MODEL_ID")
)

print("Client created successfully!")
# Out:
# Client created successfully!

# %%
# 🤖 Create the Travel Planning Agent
# This creates a conversational AI agent with specific capabilities:
# - chat_client: The AI model client for generating responses
# - instructions: System prompt that defines the agent's personality and role
# - tools: List of functions the agent can call to perform actions
agent = ChatAgent(
    chat_client=openai_chat_client,
    instructions="You are a helpful AI Agent that can help plan vacations for customers at random destinations.",
    tools=[get_random_destination]  # Our random destination tool function
)

# %%
# 🚀 Run the Agent
# Send a message to the agent and get a response
# The agent will use its tools (get_random_destination) if needed
response = await agent.run("Plan me a day trip")

# %%
# 📋 View Raw Response Object
# This shows the complete response structure including metadata
# Useful for debugging and understanding the response format
response

# %%
# 📖 Extract and Display the Travel Plan
# Get the last message from the conversation (agent's response)s
last_message = response.messages[-1]
# Extract the text content from the message
text_content = last_message.contents[0].text
# Display the formatted travel plan
print("🏖️ Travel plan:")
print(text_content)
# Out:
# 🏖️ Travel plan:
# How about a day trip to Berlin, Germany? Here's a suggested itinerary for you:
#
# ### Morning
# - **Breakfast at a Local Café**: Start your day with a traditional German breakfast at a cozy café. Try some fresh pastries and coffee.
# - **Berlin Wall Memorial**: Visit the Berlin Wall Memorial to learn about the history and significance of the Wall.
#
# ### Midday
# - **Lunch at a Street Food Market**: Head to a street food market and try some delicious local dishes like currywurst or doner kebab.
# - **Brandenburg Gate**: After lunch, take a stroll to the iconic Brandenburg Gate, a symbol of Berlin and its history.
#
# ### Afternoon
# - **Berlin Cathedral**: Visit the stunning Berlin Cathedral (Berliner Dom) and if you’re up for it, climb to the dome for a panoramic view of the city.
# - **Museum Island**: Explore Museum Island, home to several of Berlin’s most important museums. Depending on your interests, you can choose to visit one or two.
#
# ### Evening
# - **Dinner at a Local Restaurant**: Enjoy dinner at a traditional restaurant, where you can try local favorites like schnitzel or Berlin-style potatoes.
# - **Relaxing Evening Walk**: End your day with a relaxing walk along the Spree River or through Tiergarten, a large urban park.
#
# ### Optional Activities
# - If you have extra time, consider visiting the East Side Gallery, a preserved section of the Berlin Wall covered in murals, or catch a show at the opera or a local theater.
#
# Enjoy your trip to Berlin!

# %% [markdown]
# # 🎨 Agentic Design Patterns with GitHub Models (Python)
#
# ## 📋 Learning Objectives
#
# This notebook demonstrates essential design patterns for building intelligent agents using the Microsoft Agent Framework with GitHub Models integration. You'll learn proven patterns and architectural approaches that make agents more robust, maintainable, and effective.
#
# **Core Design Patterns Covered:**
# - 🏗️ **Agent Factory Pattern**: Standardized agent creation and configuration
# - 🔧 **Tool Registry Pattern**: Organized approach to managing agent capabilities
# - 🧵 **Conversation Management**: Effective patterns for multi-turn interactions
# - 🔄 **Response Processing**: Best practices for handling agent outputs
#
# ## 🎯 Key Architectural Concepts
#
# ### Design Principles
# - **Separation of Concerns**: Clear boundaries between agent logic, tools, and configuration
# - **Composability**: Building complex agents from reusable components
# - **Extensibility**: Patterns that allow easy addition of new capabilities
# - **Testability**: Design for easy unit testing and validation
#
# ### GitHub Models Integration
# - **API Compatibility**: Leveraging OpenAI-compatible endpoints
# - **Model Selection**: Choosing appropriate models for different use cases
# - **Rate Limiting**: Handling API constraints gracefully
# - **Error Recovery**: Robust error handling and retry patterns
#
# ## 🔧 Technical Architecture
#
# ### Core Components
# - **Microsoft Agent Framework**: Python implementation with GitHub Models support
# - **GitHub Models API**: Access to state-of-the-art language models
# - **OpenAI Client Pattern**: Standardized API interaction patterns
# - **Environment Configuration**: Secure and flexible configuration management
#
# ### Design Pattern Benefits
# - **Maintainability**: Clear code organization and structure
# - **Scalability**: Patterns that grow with your application needs
# - **Reliability**: Proven approaches that handle edge cases
# - **Performance**: Efficient resource utilization and API usage
#
# ## ⚙️ Prerequisites & Setup
#
# **Required Dependencies:**
# ```bash
#
# pip install agent-framework-core  -U
#
# ```
#
# **Environment Configuration (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **GitHub Models Access:**
# - GitHub account with Models access
# - Personal access token with appropriate permissions
# - Understanding of rate limits and usage patterns
#
# ## 📚 Design Pattern Categories
#
# ### 1. **Creational Patterns**
# - Agent factory and builder patterns
# - Configuration management patterns
# - Dependency injection for agent services
#
# ### 2. **Behavioral Patterns**
# - Tool execution and orchestration
# - Conversation flow management
# - Response processing and formatting
#
# ### 3. **Integration Patterns**
# - GitHub Models API integration
# - Error handling and retry logic
# - Resource management and cleanup
#
# ## 🚀 Best Practices Demonstrated
#
# - **Clean Architecture**: Layered design with clear responsibilities
# - **Error Handling**: Comprehensive exception management
# - **Configuration**: Environment-based setup for different environments
# - **Testing**: Patterns that enable effective unit and integration testing
# - **Documentation**: Self-documenting code with clear intent
#
# Ready to explore professional agent design patterns? Let's build something robust! 🌟

# %%
! pip install agent-framework-core  -U
# Out:
# Requirement already satisfied: agent-framework-core in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (1.0.0b251108)
# Requirement already satisfied: typing-extensions in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from agent-framework-core) (4.15.0)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from agent-framework-core) (2.11.10)
# Requirement already satisfied: pydantic-settings<3,>=2 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from agent-framework-core) (2.12.0)
# Requirement already satisfied: opentelemetry-api>=1.24 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from agent-framework-core) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.24 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from agent-framework-core) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.36.0 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from agent-framework-core) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai>=0.4.13 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from agent-framework-core) (0.4.13)
# Requirement already satisfied: openai>=1.99.0 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from agent-framework-core) (1.109.1)
# Requirement already satisfied: azure-identity<2,>=1 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from agent-framework-core) (1.25.1)
# Requirement already satisfied: mcp>=1.13 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from mcp[ws]>=1.13->agent-framework-core) (1.21.0)
# Requirement already satisfied: packaging>=24.1 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from agent-framework-core) (25.0)
# Requirement already satisfied: azure-core>=1.31.0 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from azure-identity<2,>=1->agent-framework-core) (1.36.0)
# Requirement already satisfied: cryptography>=2.5 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from azure-identity<2,>=1->agent-framework-core) (46.0.3)
# Requirement already satisfied: msal>=1.30.0 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from azure-identity<2,>=1->agent-framework-core) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from azure-identity<2,>=1->agent-framework-core) (1.3.1)
# Requirement already satisfied: anyio>=4.5 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (4.11.0)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (4.25.1)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.0.20)
# Requirement already satisfied: pywin32>=310 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (3.0.3)
# Requirement already satisfied: starlette>=0.27 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.49.3)
# Requirement already satisfied: uvicorn>=0.31.1 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.38.0)
# Requirement already satisfied: websockets>=15.0.1 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from mcp[ws]>=1.13->agent-framework-core) (15.0.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from openai>=1.99.0->agent-framework-core) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from openai>=1.99.0->agent-framework-core) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from openai>=1.99.0->agent-framework-core) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from openai>=1.99.0->agent-framework-core) (4.67.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from opentelemetry-api>=1.24->agent-framework-core) (8.7.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core) (1.72.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core) (1.76.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core) (1.38.0)
# Requirement already satisfied: protobuf<7.0,>=5.0 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from opentelemetry-proto==1.38.0->opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core) (5.29.5)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from opentelemetry-sdk>=1.24->agent-framework-core) (0.59b0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from pydantic<3,>=2->agent-framework-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from pydantic<3,>=2->agent-framework-core) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from pydantic<3,>=2->agent-framework-core) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from pydantic-settings<3,>=2->agent-framework-core) (1.2.1)
# Requirement already satisfied: idna>=2.8 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from anyio>=4.5->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (3.11)
# Requirement already satisfied: requests>=2.21.0 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (2.0.0)
# Requirement already satisfied: certifi in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from httpcore==1.*->httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.24->agent-framework-core) (3.23.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (0.28.0)
# Requirement already satisfied: colorama in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from tqdm>4->openai>=1.99.0->agent-framework-core) (0.4.6)
# Requirement already satisfied: click>=7.0 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from uvicorn>=0.31.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core) (8.3.0)
# Requirement already satisfied: pycparser in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (2.23)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\malte\desktop\coding\agents\venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity<2,>=1->agent-framework-core) (2.5.0)
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 📦 Import Core Libraries for Agent Design Patterns
import os                     # Environment variable access for configuration management
from random import randint    # Random selection utilities for tool functionality

from dotenv import load_dotenv  # Secure environment configuration loading

# %%
# 🤖 Import Microsoft Agent Framework Components  
# ChatAgent: Core agent orchestration class following factory pattern
# OpenAIChatClient: GitHub Models integration following adapter pattern
from agent_framework import ChatAgent
from agent_framework.openai import OpenAIChatClient

# %%
# 🔧 Configuration Loading Pattern
# Implement configuration management pattern for secure credential handling
# This follows the external configuration principle for cloud-native applications
load_dotenv()
# Out:
# True

# %%
# 🛠️ Tool Function Design Pattern
# Implements the Strategy Pattern for pluggable agent capabilities
# This demonstrates clean separation of business logic from agent orchestration
def get_random_destination() -> str:
    """Get a random vacation destination using Repository Pattern.
    
    This function exemplifies several design patterns:
    - Strategy Pattern: Interchangeable algorithm for destination selection
    - Repository Pattern: Encapsulates data access logic
    - Factory Method: Creates destination objects on demand
    
    Returns:
        str: A randomly selected destination following consistent format
    """
    # Data Repository Pattern: Centralized destination data management
    destinations = [
        "Barcelona, Spain",      # Mediterranean cultural hub
        "Paris, France",         # European artistic center
        "Berlin, Germany",       # Historical European capital
        "Tokyo, Japan",          # Asian technology metropolis
        "Sydney, Australia",     # Oceanic coastal city
        "New York, USA",         # American urban center
        "Cairo, Egypt",          # African historical capital
        "Cape Town, South Africa", # African scenic destination
        "Rio de Janeiro, Brazil",  # South American beach city
        "Bali, Indonesia"          # Southeast Asian island paradise
    ]
    
    # Factory Method Pattern: Create destination selection on demand
    return destinations[randint(0, len(destinations) - 1)]

# %%
openai_chat_client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id=os.environ.get("GITHUB_MODEL_ID"))

# %%
AGENT_NAME ="TravelAgent"

AGENT_INSTRUCTIONS = """You are a helpful AI Agent that can help plan vacations for customers.

Important: When users specify a destination, always plan for that location. Only suggest random destinations when the user hasn't specified a preference.

When the conversation begins, introduce yourself with this message:
"Hello! I'm your TravelAgent assistant. I can help plan vacations and suggest interesting destinations for you. Here are some things you can ask me:
1. Plan a day trip to a specific location
2. Suggest a random vacation destination
3. Find destinations with specific features (beaches, mountains, historical sites, etc.)
4. Plan an alternative trip if you don't like my first suggestion

What kind of trip would you like me to help you plan today?"

Always prioritize user preferences. If they mention a specific destination like "Bali" or "Paris," focus your planning on that location rather than suggesting alternatives.
"""

# %%
agent = ChatAgent(
        name = AGENT_NAME,
        chat_client=openai_chat_client,
        instructions=AGENT_INSTRUCTIONS,
        tools=[get_random_destination]
)

# %%
thread = agent.get_new_thread()

# %%
response1 = await agent.run("Plan me a day trip",thread= thread)

# %%
last_message = response1.messages[-1]
text_content = last_message.contents[0].text
print("Travel plan:")
print(text_content)
# Out:
# Travel plan:
# Hello! I'm your TravelAgent assistant. I can help plan vacations and suggest interesting destinations for you. Could you please specify a location for your day trip?

# %%
response2 = await agent.run("I don't like that destination. Plan me another vacation.",thread= thread)

# %%
last_message = response2.messages[-1]
text_content = last_message.contents[0].text
print("Change plan:")
print(text_content)
# Out:
# Change plan:
# How about a vacation in New York, USA? There’s so much to see and do there! Here are some highlights you might enjoy:
#
# 1. **Central Park**: A beautiful place to walk, bike, or have a picnic.
# 2. **Times Square**: Experience the bustling energy of this iconic spot.
# 3. **The Metropolitan Museum of Art**: Explore one of the largest and most prestigious art museums in the world.
# 4. **Broadway**: Catch a show in the famous theater district.
# 5. **Statue of Liberty & Ellis Island**: Learn about the history and significance of these landmarks.
#
# Would you like specific recommendations for activities, dining, or accommodations in New York?
